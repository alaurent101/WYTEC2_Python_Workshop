# %%
# %matplotlib inline

# %% [markdown]
# # WYTEC2 - Python Coding and Data Management
# Created by:\
# Dr. Diego Ibarra <br>
# Contact: https://diegoibarra.ca/
#
# Modified by:\
# Dr. Arnaud Laurent <br>
#
# --------------------------------

# %% [markdown]
# ## Workshop requirements
#
# There are 2 ways to carry on with the workshop:
#
# 1. Using **Anaconda** (on your computer, install required)\
#     We will use Spyder (desktop, most advanced) and JupyterLab (notebooks, most user friendly)
# 2. Using a **Binder** (online)\
#    You can run and modify code during the workshop, but changes are not saved. The **Binder** is that same as the **Workshop notebook** but you can run the code within.

# %% [markdown]
# ## If option 1: Install/Download BEFORE the workshop (you probably already did this)
#
# Do the following BEFORE the beginning of the workshop (ideally the day before). This takes about 40 minutes, at reasonably good internet speed.
#
# 1. Install **Anaconda**, which is a free "bundle" of Python and many modules, libraries and other programs commonly used in scientific research. Please install **Anaconda** from here: https://www.anaconda.com/download
#
# 2. Once **Anaconda** finishes installing, open the **Anaconda Navigator**. Sometimes this is automatically opened after the installation finishes. If not, search in the Windows Taskbar (in Mac, search in the Launchpad) for "Anaconda Navigator".
# 3. Once Anaconda Navigator is open, take a look at the available applications, find the application named “**Spyder**” (option 1a) and “**JupyterLab**”. If it is already installed, there will be a “Launch” button… if it is NOT installed, there will be a “Install” button. Make sure **Spyder** and **JupyterLab** are installed (by clicking on the ”Install” button)… but you may NOT want to “launch” it just yet. Wait until you finish installing the packages shown below.
# 4. Open the **Anaconda Prompt** (Windows) or **Terminal** (Mac). Easiest way is by searching in the Windows Taskbar the term "Anaconda Prompt" (Windows) or search in the Launchpad for "Terminal" (Mac). Then follow the next ste to install 3 modules (i.e. netcdf4, cartopy and cmocean):
#
# * Install `netcdf4`, by copy-pasting in the **Anaconda Prompt (or Terminal)**:
# <div class='terminalBlock'>conda install -c anaconda netcdf4</div>
#
#    * Click [Enter]
#    * If it asks you "are you sure?", type "y" and click [Enter] again.<br><br>
#
# * Install `cartopy`, by copy-pasting in the **Anaconda Prompt (or Terminal)**:
# <div class='terminalBlock'>conda install -c conda-forge cartopy</div>
#
#    * Click [Enter]
#    * If it asks you "are you sure?", type "y" and click [Enter] again.<br><br>
#
# * Install `cmocean`, by copy-pasting in the **Anaconda Prompt (or Terminal)**:
# <div class='terminalBlock'>conda install -c conda-forge cmocean</div>
#
#    * Click [Enter]
#    * If it asks you "are you sure?", type "y" and click [Enter] again.
#
# 5. Get the workshop files from **GitHub**. Download the workshop repository from here: https://github.com/alaurent101/WYTEC2_Python_Workshop/archive/refs/heads/main.zip
#
#    Unzip the file anywhere on your computer and rename the folder **WYTEC2_Python_Workshop**. This will be the base location for the workshop.

# %% [markdown]
# ## Workshop mechanics (how to work through this workshop)
#
# For this workshop you will need 3 programs (sometimes 4):
#
# 1. **Workshop notebook**: It is this [web-page](https://nbviewer.org/github/alaurent101/WYTEC2_Python_Workshop/blob/main/WYTEC2_PythonTutorial.ipynb), which has the instructions on what to do in the lab. If you are reading "this" you already found Workshop manual.
# 2. **Spyder**: This is the desktop program that you will use to write and run Python code. We'll talk more about **Spyder** below.
# 3. **JupyterLab**: This is the notebook program that you will also use to write and run Python code. We'll talk more about **JupyterLab** below.
# 4. **Terminal**: Every once in a while you will need to install additional Python modules. This is done in the **Terminal**. More on this below.
#
# In the first part of the workshop, you will be required to read along the **Workshop notebook** and copy-paste code from the **Workshop notebook** into **Spyder** to run it. This will create output in the form of numbers, graphs, maps, etc. So you will be jumping back and forth between the **Workshop notebook** and **Spyder** throughout the first part of the Workshop. If you chose the **Binder** option you can run the code directly from there.\
# In the second part of the workshop, we will work directly on the **Workshop notebook** with **JupyterLab**. If you chose the **Binder** it would look the same (online version).\
# Every once in a while you will need to answer <span style="background-color:#FAB57F;color:balck;font-size:15px;border:1px solid #FFA500;padding:1px">questions</span>, which are written inside orange boxes like the one below. The questions are just bring focus to elements that should be paying attention to. However, there is no grade associated with the questions. It is up to you to try to solve the question correctly.

# %% [markdown]
# <div class="alert alert-warning">
#
# This is just a sample question to show you how questions look like. All good to continue?
#
# </div>

# %% [markdown]
# ## Where is my code?
#
# Data, code and the results produced by the code can be stored in many places, including **"the cloud"** (e.g. Google-Drive, GitHub, a website, etc.) and physical computers including the computer that you are working on at this moment. Additionally, within your computer, data and code can be stored in the **hard-drive**, in **memory** and on the **screen**.
#
# <img src="./images/cloud_computer.png" width="500px">
#
# Note that:
# * **Computers** can ONLY see and work with code and data stored in **memory**
# * **Humans** can ONLY see code and data shown on the **screen**
# * When turning your computer off, code/data in both the **memory** and the **screen** are <span style='color:red'>lost forever!</span> Therefore, make sure that you save your work on your **hard-drive** or **the cloud**, before turning your computer off.
#
# We will see below how to move code (and data) between all these storage areas (i.e. memory, hard-drive, screen, cloud). <span class="important"></span> keeping track of where is your code/data stored, is one of the most common sources of errors during coding.

# %% [markdown]
# ## Anaconda (downloading and installing Python)
#
# <img src="./images/Python_logo.png" width="300px">
#
# <img src="./images/anaconda_logo.png" width="300px">
#
# There are many ways to install Python. Here, we'll used one of the most common methods... we installed `Anaconda` (likely you already did this earlier, in preparation for this workshop!). `Anaconda` is a free "bundle" of Python and many modules, libraries and other programs commonly used in scientific research. If you haven't done so, please install `Anaconda` from here: https://www.anaconda.com/download
#
# Note that when you installed `Anaconda`, a lot of code was copied from **"The Cloud"** into your **hard-drive**, in a location that we will call "the Python Directory". The actual location of "the Python Directory" is not important to us in this workshop. However if you are curious and try to find it, just make sure that you **DO NOT** move, delete or add anything within "the Python Directory"! You can break Python's proper functioning.

# %% [markdown]
# ## Spyder
#
# <img src="./images/Spyder_logo.png" width="300px">
#
# Most people do "coding" (in any programming language) using an **"Integrated Development Environment" (IDE)**, which are programs designed to make "coding" easier. **IDE's** make it easier to run your code, get help, manage multiple projects and files, color-code your code as you write it, etc. **IDE's** are like a Swiss-army-knife for coding. Many **IDE's** are free. Take a look at [this list of IDE's](https://en.wikipedia.org/wiki/Comparison_of_integrated_development_environments)
#
# In this lab, we'll use **Spyder**, which is a free "Integrated Development Environment" that comes included in `Anaconda` and that is especially designed to work with Python. You should already have it installed in your computer if you downloaded `Anaconda`.
#
# * To open ***Spyder***, search in the taskbar for "Spyder", the program looks as follows:
#
# <img src="./images/spyder.png" width="1000px">
#
# Note that when you open **Spyder**, behind the scenes a bunch of code was loaded into **memory** from "the Python Directory" (i.e. **hard-drive**).
#
#
# ### Spyder's overview
#
# The Spyder screen is divided in multiple panels. The two most important are the ***Console*** and the ***Editor***.
#
# <img src="./images/editor_console.png" width="1000px">

# %% [markdown]
# ### Spyder's "Console"
# The ***Console*** (also known as the interpreter) is a live instance of Python. This is the place where Python will display error messages, warnings, and some code output. The ***Console*** is also where you can quickly interact with Python by writing code and then clicking [Enter] (note that when you click [Enter], anything you wrote on the ***Console*** will be loaded to memory and executed immediately).
#
# Note that, to help you figure out what to type in the "Console" and what to type (or copy-paste) in the "Editor", we added a small colored box with instructions above every "code box" (red to type in "Console" and green to type in "Editor").
#
# Let's try it:
#
# <br>
# <div class="use_console"></div>

# %%
import urllib.request 

lat = [-5,30]
lon = [0,360] # Longitude goes from 0 to 360 so we need to download all longitudes to plot accross prime meridan
time = '2025-11-10T12:00:00Z'

url = f"https://oceanwatch.pifsc.noaa.gov/erddap/griddap/CRW_sst_v3_1.nc?analysed_sst%5B({time}):1:({time})%5D%5B({lat[0]}):1:({lat[1]})%5D%5B({lon[0]}):1:({lon[1]})%5D" 

urllib.request.urlretrieve(url, "./data/sst.nc")
# Out:
# ('./data/sst.nc', <http.client.HTTPMessage at 0x14e87bad0>)

# %%
import xarray as xr 
import matplotlib.pyplot as plt

# Load dataset
ds = xr.open_dataset('data/sst.nc',decode_cf=True)

# Convert longitude from 0:360 to -180:180
ds["longitude"] = (ds["longitude"] + 180) % 360 - 180
ds = ds.sortby("longitude")

# %%
# Check this documentation for plotting with Xarray
# https://docs.xarray.dev/en/stable/user-guide/plotting.html

ds.analysed_sst.plot()
ax = plt.gca()
ax.set_xlim([-30,13])
ax.set_ylim([-5,25])
# Out:
# (-5.0, 25.0)

# %%
# https://oceanwatch.pifsc.noaa.gov/erddap/griddap/CRW_sst_v3_1.html
# https://coastwatch.gitbook.io/satellite-course/tutorials/python-tutorial/1.-how-to-work-with-satellite-data-in-python

# %%
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
import matplotlib.colors  as colors
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

pc = ccrs.PlateCarree()
extent = [-30, 13, -5, 25]
cmin = 15
cmax = 30

norm1 = colors.Normalize(vmin=cmin, vmax=cmax)
rivers_50m = cfeature.NaturalEarthFeature('physical', 'rivers_lake_centerlines', '50m')

fig = plt.figure(figsize=(8,6))
ax1 = plt.axes(projection=ccrs.Mercator())

h1 = ds.analysed_sst.plot(ax=ax1, norm=norm1, add_colorbar=False, transform=pc)

plt.plot(lon,lat,'r',marker='o', transform=pc)

ax1.set_extent(extent)
ax1.add_feature(cartopy.feature.LAND, edgecolor='none', facecolor='lightgrey', lw=0.5)
ax1.add_feature(cartopy.feature.LAKES, edgecolor='black', lw=0.5)
ax1.add_feature(rivers_50m, facecolor='None', edgecolor='black', lw=0.5)
ax1.coastlines(resolution='10m', color='k', linestyle='-', alpha=1, lw=0.5)

cxy = [0.50, 0.80, 0.40, 0.05]
cax = ax1.inset_axes(cxy)
cb = plt.colorbar(h1, ax=ax1, extend = 'neither', cax = cax, norm=norm1, orientation='horizontal')
cb.set_label('Sea Surface Temperature (˚C)')
cax.xaxis.set_ticks_position('top')
cax.xaxis.set_label_position('top')




gl = ax1.gridlines(crs=pc, draw_labels=True)
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlines = False
gl.ylines = False
gl.xlocator = mticker.FixedLocator([-20, -10, 0, 10, 20])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 49
#      46 gl.yformatter = LATITUDE_FORMATTER
#      48 # Cartopy makes axises invisible by default
# ---> 49 gl.xaxis.set_visible(True)
#      50 gl.yaxis.set_visible(True)
#      52 # Optionally show gridlines
#      53 #ax.grid(True, linestyle='dashed')
#
# AttributeError: 'Gridliner' object has no attribute 'xaxis'

# %%
import urllib.request 

lat = 40
lon = 345
tmin = '2022-11-12T12:00:00Z'
tmax = '2025-11-10T12:00:00Z'
url=f"https://oceanwatch.pifsc.noaa.gov/erddap/griddap/CRW_sst_v3_1.nc?analysed_sst%5B({tmin}):1:({tmax})%5D%5B({lat}):1:({lat})%5D%5B({lon}):1:({lon})%5D" 

urllib.request.urlretrieve(url, f"./data/sst_{lat}_{lon}.nc")
# Out:
# ('./data/sst_40_345.nc', <http.client.HTTPMessage at 0x302604410>)

# %%
import xarray as xr 

ds1 = xr.open_dataset(f"./data/sst_{lat}_{lon}.nc",decode_cf=True)

fig = plt.figure(figsize=(12,5))
ds1.analysed_sst.plot()
plt.xlabel('')
plt.ylabel('Sea surface temperature (˚C)')
plt.title(f'SST at {lat}˚N, {lon}˚W')
plt.show()

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# <div class="Q"><br>
#
# After you typed in the console <span class="codeX">print('hello world!')</span>... and clicked [Enter]... <br><br>
# What got displayed on the screen?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Spyder's "Working Directory"
#
# The **working directory** is the location in your computer **hard-drive** where Spyder is reading and writing files. In the top right corner (usually), Spyder will show you its **working directory**.
#
# <img src="./images/working_directory.png" width="800px">
#
# <span class="important"></span> Make sure that your ancillary data files (and later, the python code that you will be creating), are all saved in the **working directory**. You can download them directly to the **working directory**, or you can change the **working directory** to be folder where you downloaded your files.
#
# To change the **working directory**, simply chick on the "folder" icon and select the new location. When you execute Python code with instructions to write data or a figure to a file, this file will be save by default in the **working directory**.
#
# <br><div class="startTASK"></div>
#
# 1) Earlier, in the setup/downloads/installs BEFORE the workshop, you should have created a new folder named **WYTEC_Python_Workshop**. If you didn't, please do so now (see the top of this document for detailed instructions).
#
# 2) Change Spyder's **working directory** to point to your newly created **WYTEC_Python_Workshop** folder.
#
# <br>
#
# <div class="endTASK"></div><br><br>
#
# Take a look at Spyder's working directory (top-right corner) to verify that indeed Spyder is pointing to the correct location.
#
# You can also see the location of the **working directory** by typing the following in the console (then press [Enter]):
#
# <br>
# <div class="use_console"></div>

# %%
# %pwd
# Out:
# '/Users/arnaud/Library/CloudStorage/Dropbox/Work/Tutorial/WYTEC2_Python_Workshop'

# %% [markdown]
# <div class="alert alert-warning">
#
# You are starting to work on a lab that requires 2 ancillary data files and 3 ancillary python code files. You download all of these files from Google_drive into you Laptop. Which of the following describes best what happened to the data/code? <br><br>
#
# a) Data/code were copied from "the cloud" to your hard-drive<br><br>
#
# b) Data/code were copied from "the cloud" to your computers memory<br><br>
#
# c) Data/code were copied from your hard-drive to your computers memory<br><br>
#
# d) Data/code were copied from your hard-drive to your screen<br><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# You are starting to work on a lab that requires 2 ancillary data files and 3 ancillary python code files. **Where** in your laptop do you have to put these files?<br><br>
#
# a) Your "working directory"<br><br>
#
# b) The "Python directory" in your computer<br><br>
#
# c) The "Downloads" directory in your computer<br><br>
#
# d) Your Desktop<br><br>
#
# </div>

# %% [markdown]
# ### Spyder's "Editor"
# The **Editor** is the space where you write your code so that you can execute it later. The **Editor** is shown below inside the green box.
#
# <img src="./images/editor_console.png" width="800px">
#
# The **Editor** is just a text editor like Notepad (in Windows) or TextEdit (in Mac). However, Spyder's **Editor** color-codes your text so that it can be read with ease. It will also perform some basic quality control and will tell you if you made a mistake (more on this later).
#
# You can run the code you wrote in the editor by clicking on the "run" button (i.e. green triangular button shown below).
#
# <img src="./images/run_button.png" width="500px">
#
# Note that the first time you run your code the **Editor** will prompt you to save your file. You can name your file anything you want, but the extension will be automatically set as `.py`, which is the default extension for Python files. Also note that, by default, you will be prompt to save your file in the current **working directory**.
#
# After you write some code in the **Editor**, note that clicking the "save" button technically transfers code from the **Screen** into a file in your **hard-drive**. Also, if you click the "run" button, it automatically saves your code and then loads it into **memory** and executes it!

# %% [markdown]
# <div class="alert alert-info">
#
# In Spyder, you can click on [File] > [New file...] to create a new empty Python file.
#
# Make a new file, name it **test1.py**, and save it in your **working directory**.
#
# </div>

# %% [markdown]
# Note that, to help you figure out when to type or copy-paste into the "Editor" (i.e. NOT in the "Console"), we added a small GREEN colored box with instructions above every "code box".
#
# Lets do a test. Type the following in the **Editor** and click <span class="run"></span>

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# As you see, when you run the code in the ***Editor***, the output is displayed in the ***Console***

# %% [markdown]
# <div class="alert alert-warning">
#
# After you write some code in the **Editor**, what happens when you click the **"save"** button?<br><br>
#
# a) Code is saved to the hard-drive<br>
#
# b) Code is loaded to memory<br>
#
# c) Code is saved to the cloud<br>
#
# d) Code is loaded to the screen
#
# </div>

# %% [markdown]
# <div class="Q"><br>
#
# After you write some code in the **Editor**, what happens when you click the **"run"** button?<br><br>
#
# a) Code is saved to the hard-drive<br>
#
# b) Code is loaded into memory<br>
#
# c) Code is saved to the cloud<br>
#
# d) Code is loaded to the screen<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ## When to "Editor"? ...and when to "Console"?
#
# <img src="./images/editor_console.png" width="500px">
#
# It can be tricky to know when to type (or copy-paste) code in the "Editor" and when to do so in the "Console". The "Editor" is best suited for writing long (or medium length) scripts that are self-contained... while the "Console" is best for writing "on the fly" tests that are one or a few lines long.
#
# 1) **Editor:** When you use **Editor** you most save your code in a `.py` file before you can <span class="run"></span> it. The advantage of this is that you can re-use your code at a later date. Simply open your `.py` file and <span class="run"></span>it again! Use the **Editor** to write self-contained code (i.e. scripts or little programs) that you may want to re-use a later date. Examples of these self-contained scripts are shown in the real-life case studies below.
#
# 2) **Console:** The **Console** is the quickest way to enter code into Python's **"memory"** and the quickest way to query or inspect something that is already in Python's **"memory"**. The drawback is that code written in **Console** quickly disappears as you write new code... or when you turn off Spyder or your computer. <span style="color:red;">Code written in the **Console** is not very re-usable.</span> Therefore, use the **Console** when you need to do "one-offs" or "on the fly" tests.
#
# <br><br>
# <img src="./images/chicken_tacos.jpg" width="500px">
#
# If we use, as an analogy, the development of a new recipe for making "chicken tacos". You may start cooking the recipe as you write each step in your recipe book. When you get to the part about adding salt, you don't know how much salt to add... so you experiment.  You start by adding a small amount of salt (1 gr), stir and taste. If it is not enough, you ad another gram... then stir and taste... and so, on until you get the right amount of salt. Then you write in your recipe the final amount of grams of salt.
#
# In this analogy, writing in the recipe book is as writing in Spyder's **"Editor"**. Text here are clean instructions that you will need to read later to cook the recipe, so these instructions better be clean, well written, and in the appropriate order.
#
# Adding salt, stirring and tasting are "on the fly" tests to see if what you are doing is good or needs adjustment. This is the equivalent to writing in Spyder's **"Console"**.
#
# As mentioned earlier, we will be adding "red" or "green" blocks (like the ones below) to guide you when to use the **Console** and when to use the **Editor**...
#
# <div class="use_console"></div>
#
# <br>
# <div class="use_editor"></div>

# %% [markdown]
# -------------------------------
# ## Comments and statements
#
# * **Comments** are lines of text meant to be read ONLY by humans (i.e. the computer ignores these lines). Comments usually contain annotations and additional information to make easier to understand the code to the programmer. **Comments** are preceded by a **#** (hashtag)
#
# * A **Statement** is a line of text read by the computer. This is "the code". A statement contains instructions for the computer to do one or more tasks.
#
# Take a look to the sequence of statements below:

# %%
# This is a Comment because it is preceded by a # (hashtag)
a = 2

# Lets print our variables to screen
print(a) # Note that comments can be written after a statement (but not before)
# Out:
# 2

# %% [markdown]
# Above...
# * The first line is a **comment**
# * The second line is a **statement** assigning the value of `a` to be equal to 2
# * Then there is a blank line. Blank lines are ignored by Python (they exist to space the code and make it easier to read).
# * The forth line is a **comment**
# * The fifth line is a **statement** asking Python to print the value of `a` to screen. After the statement, there is another comment
#
# If you copy-paste the code above to the ***Spyder's Editor*** and click [run], it will print a `2` to the console.

# %% [markdown]
# <div class="note"> Once `a = 2` has been executed, the value of `a` will be stored "in memory" until you turn off python, until you delete `a`, or until you update `a` with a different value.</div>

# %% [markdown]
# ## Variables
# A **Variable** is a user-defined label that can be used to name anything. For example, in the **statement** above (`a = 2`) "a" is a variable. You can name variables anything you want (no punctuation thought), for example:
#
# <br>
# <div class="use_editor"></div>

# %%
my_cute_variable = 35

print(my_cute_variable)
# Out:
# 35

# %% [markdown]
# Note that it is a good practice to choose variable names that describe what is stored within the variable.

# %% [markdown]
# Also note that you can use Spyder's ***Variable explorer*** to see what variables are currently loaded into **memory**.
#
# <img src="./images/variable_explorer.png" width="800px">

# %% [markdown]
# ------------------------------
# ## Sneak-peak of Real-life case study #1: data from an oceanographic buoy in Oregon
#
# Let's take a quick look at what is coming ahead.
#
# Lets use data from an autonomous buoy in the Columbia River (Oregon, USA) that (used to) broadcasts real-time ocean data via the following server: http://columbia.loboviz.com/
#
# <table>
#   <tr>
#     <td><img src="./images/lobo.jpg" width="300px">LOBO Buoy</td>
#     <td><img src="./images/columbia_river.jpg" width="400px">Columbia River (Oregon, USA)</td>
#   </tr>
# </table>
#
# The following code load the buoy's data, and makes a simple plot.

# %%
# Import Pandas module
import pandas as pd

# Read data from file
buoy_data = pd.read_csv('./data/buoy_data.csv')

# Do quick plot
buoy_data.plot(x='date [PST]',y='temperature [C]', rot=90)
# Out:
# <Axes: xlabel='date [PST]'>

# %% [markdown]
# To see the plot you just made, click on the "Plot" tab (beside your "Variable explorer"). See below...
#
# <img src="./images/plot_explorer.png" width="800px">

# %% [markdown]
# It is pretty amazing that you can make a decent plot with just 3 lines of code.
#
#
# If you take a close look to the code, you can also see some of the principles that we just learned, like "comments" and "statements":
#
# <img src="./images/code1.png" width="600px">
#
# <img src="./images/code2.png" width="600px">

# %% [markdown]
# You can also see in the code that we created a variable (`buoy_data`) and then we used it to make a plot.
#
# <img src="./images/code3.png" width="600px">

# %% [markdown]
# But also there is a lot that we have not learned yet, like` modules`, `fundtions`, `methods`, `strings`, `floats`, etc.
#
# <img src="./images/code4.png" width="500px">
#
# We are going to learn those concepts next. Then we'll come back to the Real-life scenario #1: The Oregon Buoy.

# %% [markdown]
# -------------------------------
#
# ##  Basic data types (or "primitive" data types)
#
# In every computer language there are many data types. Each data type is best suited to handle different data, and also behaves under different rules, thus it is important to always be aware of what data type each statement is working with.
#
# Below are some of the most common data types used in Python:
#
# ### Integers
#
# **Integers** are "round" numbers (i.e. no decimal point).
#
# <br>
# <div class="use_editor"></div>

# %%
my_int = 2

print(my_int)
# Out:
# 2

# %% [markdown]
# ### Floats
# **Floats** are numbers with a decimal point.
#
# <br>
# <div class="use_editor"></div>

# %%
my_float = 2.4

print(my_float)
# Out:
# 2.4

# %% [markdown]
# ### Strings
# **Strings** are letters. Note that you need to wrap the content of the string within quotes to tell Python they are a string.
#
# <br>
# <div class="use_editor"></div>

# %%
# You can use single quotes ' or double quotes " to create strings
my_string_1 = 'hello'

my_string_2 = "2.4"

print(my_string_1)
print(my_string_2)
# Out:
# hello
# 2.4

# %% [markdown]
# #### Note that even though "2.4" is a number, it will be treated by Python as "letters". Therefore you won't be able to do math with "2.4"

# %% [markdown]
# <div class="Q"><br>
#
# What data type is the following: 324.91
#
# <br>
# a) Integer<br>
#
# b) Float<br>
#
# c) String<br>
#
# d) Boolean<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# What data type is the following: 'the house is green'
#
# <br>
# a) Integer<br>
#
# b) Float<br>
#
# c) String<br>
#
# d) Boolean<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# What data type is the following: 87572
#
# <br>
# a) Integer<br>
#
# b) Float<br>
#
# c) String<br>
#
# d) Boolean<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following line in Python... <br><br>
#
#     a = 32
#
# Then, what is "**32**"? <br><br>
#
# a) an integer<br>
#
# b) a float<br>
#
# c) a string<br>
#
# d) a variable<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following line in Python... <br><br>
#
#     a = 32
#
# Then, what is "**a**"?<br><br>
#
# a) an integer<br>
#
# b) a float<br>
#
# c) a string<br>
#
# d) a variable<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Simple operations between different data types
#
#
# You can do math with most of these data types, as long as they are of the same data type. For example:

# %%
4 + 7
# Out:
# 11

# %%
my_int * 7
# Out:
# 14

# %%
my_float / 2
# Out:
# 1.2

# %% [markdown]
# Sometimes (not always) you can do math with different data types. However, some quirks and changes may happen to the result. For example, adding an **integer** plus a **float** yields a float.

# %%
my_int + my_float
# Out:
# 4.4

# %% [markdown]
# ...but sometimes mixing data types doesn't work. For example, operations between strings and floats (or integers) <span style="color:red;">is not allowed</span> and therefore if you try to do this operation, Python will yield an ERROR.

# %%
my_float + my_string_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 my_float + my_string_1
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# "Summing" two strings simply concatenates them together:

# %%
my_string_1 + my_string_2
# Out:
# 'hello2.4'

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following lines in Python...
#
#     a = 3
#     b = 1
#
# Then, what is the result of: *a + b*<br><br>
#
# a) 4<br>
#
# b) 3<br>
#
# c) '31'<br>
#
# d) '4'<br>
#
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following lines in Python...
#
#     a = '3'
#     b = '1'
#
# Then, what is the result of: *a + b*<br><br>
#
# a) 4<br>
#
# b) 3<br>
#
# c) '31'<br>
#
# d) '4'<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# -------------------------------------------
#
# ## Objects (lists and dictionaries)
#
# Everything in Python is an object! Even the **basic data types** are objects: Integers are "Integer Objects", floats are "Float Objects", etc. Each type of object behaves under its own set of rules, therefore it is ESSENTIAL to be aware of what type of object is each of your variables.
#
# We already talked about the sometimes called **"primitive objects"** (i.e. integers, floats, strings), however python comes included with some more advanced objects (e.g. lists and dictionaries). Also, when you install new modules, often they come with their own objects (each with their own rules).
#
# Following a "cooking analogy", I like to think "primitive objects" as types of raw ingredients (e.g. liquid, powder, solid) and the more advanced objects can be thought as containers (e.g. bag, basket, jar, shelf).
#
# If you don't know what type of object is a variable, just type **`type(variableName)`**, for example:

# %%
my_var = 12.8

type(my_var)
# Out:
# float

# %% [markdown]
# ### Lists
# Lists are similar to "cell-arrays" in Matlab. "Lists" are great when you just want to append items at the end of the list, but you don't care too much about retrieving a particular item within the list.
#
# Let's do a "list"

# %%
my_list = [2,5,8,7,1,2,7]

my_list
# Out:
# [2, 5, 8, 7, 1, 2, 7]

# %% [markdown]
# To see if a variable is a `list`, you can also use `type`. See below:

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# To access an item within the list, type its index within square brackets:

# %%
my_list[0]
# Out:
# 2

# %% [markdown]
# <span class="important"></span> Note that in Python, the first index is **zero!**

# %%
my_list[1]
# Out:
# 5

# %%
my_list[2]
# Out:
# 8

# %% [markdown]
# Negative indices are counted backwards from the last item:

# %%
my_list[-1]
# Out:
# 7

# %%
my_list[-2]
# Out:
# 2

# %% [markdown]
# To access several items within the list, use a colon (i.e. :)

# %%
my_list[2:4]
# Out:
# [8, 7]

# %%
my_list[:3]
# Out:
# [2, 5, 8]

# %%
my_list[-3:]
# Out:
# [1, 2, 7]

# %% [markdown]
# Note that you can put anything you want in a list (i.e. not only integers). For example:

# %%
my_other_list = ['a','5',8,'b',1,2.88,7,'x']

my_other_list[-3:]
# Out:
# [2.88, 7, 'x']

# %% [markdown]
# <div class="Q"><br>
#
# Given the following List: <br><br>
# my_list = [2,5,8,7,1,2,7] <br><br>
# How do you access the 3rd item in the list (i.e. 8)? <br><br>
#
# a) my_list[3]<br>
#
# b) my_list[2]<br>
#
# c) my_list[5]<br>
#
# d) my_list[7]<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following List: <br><br>
# my_list = [2,5,8,7,1,2,7] <br><br>
# How do you access the last 4 items in the list (i.e. 7,1,2,7)? <br><br>
#
# a) my_list[4]<br>
#
# b) my_list[-4:]<br>
#
# c) my_list[1:4]<br>
#
# d) my_list[2:4]<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are similar to "structure-arrays" in Matlab. A "Dictionary" stores items in a way that resembles a dictionary. You look up a "keyword" (e.g. "apple") and your immediately get the contents (i.e. "Red round fruit that tastes good").
#
# Dictionaries are great to quickly find a specific item within the dictionary.
#
# Lets make a dictionary:

# %%
my_dict = {'name':'Juan', 'age':27, 'gender':'male'}

my_dict
# Out:
# {'name': 'Juan', 'age': 27, 'gender': 'male'}

# %% [markdown]
# To see if a variable is a `Dictionary`, you can also use `type`. See below:

# %%
type(my_dict)
# Out:
# dict

# %% [markdown]
# Let's query the dictionary using the keywords:

# %%
my_dict['age']
# Out:
# 27

# %%
my_dict['name']
# Out:
# 'Juan'

# %% [markdown]
# <div class="Q"><br>
#
# Given the following Dictionary: <br><br>
# my_dict = {'name':'Juan', 'age':27, 'gender':'male'} <br><br>
# How do you access the contents stored under the 'age' key (i.e. 27)? <br><br>
#
# a) my_dict['name']<br>
#
# b) my_dict['age']<br>
#
# c) my_dict['gender']<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following lines in Python...
#
#     a = [3,7,1,9]
#     b = {'1':3, '2':7, '3':1, '4':9 }
#
# Then, what type of object is **a**?<br><br>
#
#
# a) list<br>
#
# b) dictionary<br>
#
# c) integer<br>
#
# d) float<br>
#
# e) string<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# If you execute the following lines in Python...
#
#     a = [3,7,1,9]
#     b = {'1':3, '2':7, '3':1, '4':9 }
#
# Then, what type of object is **b**?<br><br>
#
#
# a) list<br>
#
# b) dictionary<br>
#
# c) integer<br>
#
# d) float<br>
#
# e) string<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ---------------------------------------------
#
# ## Functions and methods
#
# **Functions** and **methods** are how you "do stuff" in Python. With one line of code you can do things like calculate a mean, or do a plot, or do a complicated statistical analysis. In essence, both **functions** and **methods** are code that accept an "input", do something to the input, and spits out an "output". The only thing you need to know and remember is the name of the function (or method). Arguably, learning Python is mostly learning the names of the available functions and methods.
#
# ### Functions
#
# Functions are used following the "nomenclature" below:
#
#
# <div class="nomenclature">output = FunctionName(input)</div>
#
#
# We already used a few functions above, namely the "print" function...

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ...and the "type" function

# %%
type(124.87)
# Out:
# float

# %% [markdown]
# In both case the output was simply displayed to screen, which happens when you do not specify what to do with the output. Below are a few examples where the output is saved to a variable:
#
# First lets do a list... and then apply some functions to it.

# %%
mylist = [4,7,2,9,6,3,7,8,5,10]


# Calcualte the sum
sum(mylist)
# Out:
# 61

# %% [markdown]
# In the case above, ***FunctionName*** is `sum`, ***input*** is `mylist`, and ***output*** is `61`

# %%
# Figure out the maximum of a list
a = max(mylist)

a
# Out:
# 10

# %% [markdown]
# In the case above, ***FunctionName*** is `max`, ***input*** is `mylist`, and ***output*** is `a`

# %%
# Figure out the minimum of a list
min(mylist)
# Out:
# 2

# %%
# Get the "length" of a list
len(mylist)
# Out:
# 10

# %%
# Get the "type" of Object
type(mylist)
# Out:
# list

# %% [markdown]
# <div class="note">
#
# <br>
#
# Here is a list of the basic Functions built-in within Python:
#
# https://docs.python.org/3/library/functions.html
#
# <br>
#
# </div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = max(my_list)<br><br>
# What is the name of the function?<br><br>
#
# a) c<br>
#
# b) max<br>
#
# c) my_list<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = max(my_list)<br><br>
# What is the "input"? <br><br>
#
# a) c<br>
#
# b) max<br>
#
# c) my_list<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = max(my_list)<br><br>
# What is the "output"? <br><br>
#
# a) c<br>
#
# b) max<br>
#
# c) my_list<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following List: <br><br>
# my_list = [2,3,1] <br><br>
# ... and the following statement:<br><br>
# output =  max(my_list)<br><br>
# What is the value of "output"? <br><br>
#
# a) 2<br>
#
# b) 3<br>
#
# c) 1<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following List: <br><br>
# my_list = [2,3,1] <br><br>
# ... and the following statement:<br><br>
# output =  len(my_list)<br><br>
# What is the value of "output"?<br><br>
#
# a) 2<br>
#
# b) 3<br>
#
# c) 1<br>
#
# d) None of the above<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Methods
#
# Methods are similar to functions, but they follow a different "nomenclature":
#
# <div class="nomenclature">output = input.MethodName(arguments)</div>
#
# The ***arguments*** are additional information sometimes required by the method.
#
# Note that before you can "apply" ***MethodName*** to the ***input*** object, we first need to create the ***input*** object.
#
# For example...

# %%
# First we create a "list" object
mylist = [4,7,2,9,6,3,3,8,5,10]

# Then, this appends the number "2" to the end of mylist
mylist.append(2)

print(mylist)
# Out:
# [4, 7, 2, 9, 6, 3, 3, 8, 5, 10, 2]

# %% [markdown]
# Here the number 2 in the parenthesis is an ***argument***.
#
# Let do some more...

# %%
# This finds the number "7" in mylist, and removes it
mylist.remove(7)

print(mylist)
# Out:
# [4, 2, 9, 6, 3, 3, 8, 5, 10, 2]

# %%
#This sorts mylist. Note that this method does not require any arguments, thus the parenthesis are left empty ()
mylist.sort()

print(mylist)
# Out:
# [2, 2, 3, 3, 4, 5, 6, 8, 9, 10]

# %%
#This finds the number "5" in mylist and returns its index
mylist.index(8)
# Out:
# 7

# %% [markdown]
# By now you probably figured out that each object type (e.g. lists or dictionaries) has its own built-in `methods`. Use Google to find out the available methods for a particular object type. For example, if you want to see the available methods for "list" objects, Google: `python methods list`

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = mylist.remove(7)<br><br>
# What is the "input"?<br><br>
#
# a) c<br>
#
# b) mylist<br>
#
# c) remove<br>
#
# d) 7<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = mylist.remove(7)<br><br>
# What is the "output"? <br><br>
#
# a) c<br>
#
# b) mylist<br>
#
# c) remove<br>
#
# d) 7<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = mylist.remove(7)<br><br>
# What is the "MethodName"? <br><br>
#
# a) c<br>
#
# b) mylist<br>
#
# c) remove<br>
#
# d) 7<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Given the following statement: <br><br>
# c = mylist.remove(7)<br><br>
# What is the "argument"? <br><br>
#
# a) c<br>
#
# b) mylist<br>
#
# c) remove<br>
#
# d) 7<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ## Modules

# %% [markdown]
# So far we used some of the built-in functions of Python (e.g. `type`, `len`, `max`), as well as some methods of Python's built-in objects (e.g. methods of the `list` object); however, there are **A LOT MORE!**. You can import functions and objects (with its associated methods) from external **"modules"** (or "packages")... therefore you have **thousands** of functions and methods at your disposal.
#
# To be able to use a **"module"**, you first need to **(1) install the module**, and then you need to **(2) import the module**.
#
# <img src="./images/install_import.png" width="500px">
#
# 1. When you **"install"** a module, behind the scenes the module's code is downloaded from the cloud and written in the default "Python Directory" in your hard-drive. <span style="color:red;">This step only needs to be done once.</span> The module will remained installed in your hard-drive "forever" (or until you decide to uninstall it).
#
# 2. When you **"import"** a module, behind the scenes the module's code is loaded into **Memory** (from the default "Python Directory" where it was installed in step 1). This step needs to be done every time you run the program that needs the module. Conveniently, you can simply use an `import` statement at the beginning of your code so the required module is loaded automatically every time you run your code.
#
# When you install `Anaconda`, the Anaconda installer **"installs"** Python and also **"installs"** a bunch of commonly used **modules**. Therefore you can simply `import` them and use them right away. Below is an example about how to import the Module `math` and use one of its functions (note that we'll learn how to **"install"** new modules at the end of this lab).

# %%
# First import the module "math"
import math

# Then use the function "sin" within the module "math"
math.sin(mylist[0])
# Out:
# 0.9092974268256817

# %% [markdown]
# <span class="important"></span> When using a function from an imported module, you need to add the **module name** to the **function name**. Thus the "nomenclature" is slightly modified as shown below:
#
# <div class="nomenclature">output = ModuleName.FunctionName(input)</div>

# %% [markdown]
# ------------------------------
# ## Real-life case study #1: Data from an oceanographic buoy in Oregon
#
# Up to here, everything probably sounds easy, but not really that useful. Lets put it all together in a real-life application using 1 function and 1 method.
#
# There was an autonomous buoy in the Columbia River (Oregon, USA) that used to broadcast real-time ocean data via the following server: http://columbia.loboviz.com/
#
# <table>
#   <tr>
#     <td><img src="./images/lobo.jpg" width="300px">LOBO Buoy</td>
#     <td><img src="./images/columbia_river.jpg" width="400px">Columbia River (Oregon, USA)</td>
#   </tr>
# </table>
#
# The following code load the buoy's data, and makes a simple plot.
#
# In Spyder's ***Editor*** open a new file and save it as <span class="file">buoy.py</span>. Copy-paste the code below to your new file and click <span class='run'></span>

# %%
# Import Pandas module
import pandas as pd

# Read data from file
buoy_data = pd.read_csv('./data/buoy_data.csv')

# Do quick plot
buoy_data.plot(x='date [PST]',y='temperature [C]', rot=90)
# Out:
# <Axes: xlabel='date [PST]'>

# %% [markdown]
# To see the plot you just made, click on the "Plot" tab (beside your "Variable explorer"). See below...
#
# <img src="./images/plot_explorer.png" width="800px">

# %% [markdown]
# ### Code Explanation:
#
# #### Line 1:

# %%
import pandas as pd

# %% [markdown]
# Here we imported the `pandas` module, which is a fantastic data analysis library (learn more: http://pandas.pydata.org/ ). Note that we also "nicknamed" the module `pd` so that we don't have to write the long name "pandas" before each function.
#
# #### Line 2:

# %%
buoy_data = pd.read_csv('buoy_data.csv')

# %% [markdown]
# This line **load the data** from the file `buoy_data.csv` and puts it into a new variable that we called `buoy_data`. We named our variable with the same name as the file (i.e. buoy_data), but you can use any name you want (e.g. my_ocean_data). However, using variable names that describe "what's in them" is encouraged.
#
# Below is the breakdown of the statement:
# * **MethodName.FunctionName:** `pd.read_csv`
# * **Input:** `buoy_data.csv`
# * **output:** `buoy_data`
#
# So, we used 1 arguments in this example (i.e. `buoy_data.csv`), but **how do we know what arguments are available and how to use them?**
#
# **ANSWER:** Google the function name (i.e. Google: `pd.read_csv`)
#
#
# Note that the output, `buoy_data`, is a pandas DataFrame object. We'll talk more about this below.
#
# #### Line 4:

# %%
buoy_data.plot(x='date [PST]',y='temperature [C]', rot=90)
# Out:
# <Axes: xlabel='date [PST]'>

# %% [markdown]
# Here we applied the method **plot** to the pandas DataFrame object **buoy_data**. The output is a plot!
#
# -------------------------

# %% [markdown]
# ### Inspecting your code
#
# Before we do anything with our newly downloaded data, lets take a minute to examine our code...

# %% [markdown]
# <div class="Q"><br>
#
# In the code above (i.e. Real-life case study 1: Downloading real-time data from an oceanographic buoy in Oregon)...
#
# <br><br>
# ...What is: pandas
# <br><br><br>
# a) a variable<br>
#
# b) a module<br>
#
# c) a function<br>
#
# d) a list<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# In the code above (i.e. Real-life case study 1: Downloading real-time data from an oceanographic buoy in Oregon)...
#
# <br><br>
# ...What is: pd.read_csv
#
# <br><br><br>
# a) a variable<br>
#
# b) a module<br>
#
# c) a function<br>
#
# d) a list<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# In the code above (i.e. Real-life case study 1: Downloading real-time data from an oceanographic buoy in Oregon)...
#
# <br><br>
# ...What is: buoy_data
#
# <br><br><br>
# a) a variable<br>
#
# b) a module<br>
#
# c) a function<br>
#
# d) a list<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# In the code above (i.e. Real-life case study 1: Downloading real-time data from an oceanographic buoy in Oregon)...
#
# <br><br>
# ...What is: .plot
#
# <br><br><br>
# a) a variable<br>
#
# b) a module<br>
#
# c) a function<br>
#
# d) a method<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# Take a look to the plot of temperature in the Colorado River (Oregon, USA).   <br><br>
#
# What do you think causes the oscillations in temperature?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Inspecting buoy_data:
#
# Making a quick plot is useful, but we likely also want to look at the actual data. Lets start by inspecting what type of object is **buoy_data**
#
# <br>
# <div class="use_console"></div>

# %%
type(buoy_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# As I said above, **buoy_data**, is a pandas DataFrame object (a *pandas.core.frame.DataFrame* to be specific). It is very similar to the core DataFrame in R. If you are not familiar with R, a good way to describe a pandas DataFrame is a table like an Excel spread-sheet, with rows and columns.
#
# To actually take look into **buoy_data**, simply type it into the Console and click [Enter]:
#
# <br>
# <div class="use_console"></div>

# %%
buoy_data
# Out:
#            date [PST]  temperature [C]
# 0     2018-08-20 0:00            22.31
# 1     2018-08-20 1:00            22.29
# 2     2018-08-20 2:00            22.24
# 3     2018-08-20 3:00            22.18
# 4     2018-08-20 4:00            22.13
# ..                ...              ...
# 451  2018-09-07 19:00            20.21
# 452  2018-09-07 20:00            20.18
# 453  2018-09-07 21:00            20.16
# 454  2018-09-07 22:00            20.18
# 455  2018-09-07 23:00            20.29
#
# [456 rows x 2 columns]

# %% [markdown]
# This shows you the top and bottom of the table as well as some descriptors (e.g. 192 rows × 2 columns). If you only want to show the first few rows, apply the method **.head** to the **buoy_data** object:
#
# <br>
# <div class="use_console"></div>

# %%
buoy_data.head()
# Out:
#         date [PST]  temperature [C]
# 0  2018-08-20 0:00            22.31
# 1  2018-08-20 1:00            22.29
# 2  2018-08-20 2:00            22.24
# 3  2018-08-20 3:00            22.18
# 4  2018-08-20 4:00            22.13

# %% [markdown]
# <div class="Q"><br>
#
# After you ran the following statement  <br><br>
# buoy_data.head()<br><br>
# What is the temperature (C) in the first record in the table?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# Similarly you can show only the end of the table by applying the **.tail** method to the **buoy_data** object:
#
# <br>
# <div class="use_console"></div>

# %%
buoy_data.tail()
# Out:
#            date [PST]  temperature [C]
# 451  2018-09-07 19:00            20.21
# 452  2018-09-07 20:00            20.18
# 453  2018-09-07 21:00            20.16
# 454  2018-09-07 22:00            20.18
# 455  2018-09-07 23:00            20.29

# %% [markdown]
# <div class="Q"><br>
#
# After running the following statement  <br><br>
# buoy_data.tail()<br><br>
# What is the last temperature in your table?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# Instead of referring to the entire table (**buoy_data**), you can just refer to one column. The table is a Python dictionary where the "header" of each column is the dictionary key which will return the entire column. For example, to refer ONLY to the temperature column:
#
# <br>
# <div class="use_console"></div>

# %%
buoy_data['temperature [C]']
# Out:
# 0      22.31
# 1      22.29
# 2      22.24
# 3      22.18
# 4      22.13
#        ...
# 451    20.21
# 452    20.18
# 453    20.16
# 454    20.18
# 455    20.29
# Name: temperature [C], Length: 456, dtype: float64

# %% [markdown]
# Lets calculate the average temperature by applying the **.mean** method only to the 'temperature [C]' column:
#
# <br>
# <div class="use_console"></div>

# %%
buoy_data['temperature [C]'].mean()
# Out:
# 20.861206140350877

# %% [markdown]
# Similarly, you can calculate the minimum, maximum, median, standard deviation, mode, etc...

# %%
buoy_data['temperature [C]'].min()
# Out:
# 19.64

# %%
buoy_data['temperature [C]'].max()
# Out:
# 22.42

# %%
buoy_data['temperature [C]'].median()
# Out:
# 20.74

# %%
buoy_data['temperature [C]'].std()
# Out:
# 0.731239256140188

# %%
buoy_data['temperature [C]'].mode()
# Out:
# 0    20.12
# Name: temperature [C], dtype: float64

# %% [markdown]
# ---------------------------------
#
# ## Real-life case study #2: Downloading real-time data from a Glider (Autonomous Underwater Vehicle) from Nova Scotia
#
# <table>
#   <tr>
#     <td><img src="./images/slocum_glider.jpg" width="400px">Slocum Glider</td>
#     <td><img src="./images/otn200.png" width="500px">Current deployment</td>
#   </tr>
# </table>
#
#
#
# The code below pulls data from a glider currently deployed off the coast of Nova Scotia (http://gliders.oceantrack.org/). The code also does a simple quality control and makes a rough depth-vs-time scatter plot.
#
# In **Spyder** open a new file, name it <span class="file">glider.py</span>, copy-paste the code below and click <span class="run"></span>.

# %%
# Import Pandas module
import pandas as pd

# Read data from file
glider_data = pd.read_csv('glider_data.csv',sep=',')

# Quality Control: Filter out data above 40oC and below -8oC
glider_data = glider_data[(glider_data.sci_water_temp < 40) & (glider_data.sci_water_temp > -8)]

# Quality Control: Filter out data too close to the surface
glider_data = glider_data[glider_data.depth > 3]

# Make a scatter plot
glider_data.plot.scatter('unixtime',
                         'depth',
                         c='sci_water_temp',
                         marker='o',
                         edgecolor='none',
                         cmap='viridis',
                         ylim=[glider_data['depth'].max(),0],
                         figsize=[19,9])
# Out:
# <Axes: xlabel='unixtime', ylabel='depth'>

# %% [markdown]
# The left side of the graph shows the data collected at the beginning of the deployment. The right side of the graph shows the most recently collected data. The top of the graph shows the temperature close to the surface (3 m) while data points at the bottom of the graph represent temperature near the bottom (~150 m). Note that there was a thermocline at about 20 m depth, where water temperature was noticeably warmer between 3 and 20 m.

# %% [markdown]
# It is also useful to plot the glider path from above (i.e. "bird's eye" view). We can do that with the .plot method:
#
# <br>
# <div class="use_editor"></div>

# %%
# Bird's eye view transect
glider_data.plot(x='lon',y='lat',style='.-', rot=90)
# Out:
# <Axes: xlabel='lon'>

# %% [markdown]
# You can see "gaps" where the glider was moving, but not recording. You can also see those gaps in the color-plot of temperature/depth/time shown above.

# %% [markdown]
# Take a look inside `glider_data`
#
# <br>
# <div class="use_console"></div>

# %%
glider_data.head()
# Out:
#        unixtime        lat        lon      depth  sci_water_temp
# 1  1.469369e+09  48.337438 -64.171928  90.088686          0.9753
# 2  1.469369e+09  48.337437 -64.171921  90.123090          0.9856
# 3  1.469369e+09  48.337436 -64.171909  90.179436          0.9772
# 4  1.469369e+09  48.337435 -64.171897  90.240740          0.9767
# 5  1.469369e+09  48.337433 -64.171884  90.303295          0.9759

# %% [markdown]
# Tough question: What is the maximum depth recorded in this dataset? Hint: Apply the **.max** method on the "depth" column.

# %% [markdown]
# <div class="Q"><br>
#
# What is the **maximum** depth recorded in glider_data?  <br><br>
#
# a) 125.1<br>
# b) 198.6<br>
# c) 145.2<br>
# d) 250.0<br>
#
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# More tough questions:

# %% [markdown]
# <div class="Q"><br>
#
# What is the **maximum** water temperature recorded in the "sci_water_temp" column within glider_data?  <br><br>
#
# a) 10.1<br>
# b) 23.6<br>
# c) 18.7<br>
# d) 9.2<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# What is the **minimum** water temperature recorded in the "sci_water_temp" column within glider_data?  <br><br>
#
# a) -10.1<br>
# b) 3.6<br>
# c) 0.7<br>
# d) -0.2<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# How many records are in the "sci_water_temp" column within glider_data?   <br><br>
#
# a) 2356<br>
# b) 798<br>
# c) 10731<br>
# d) 359712<br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ## Installing new modules
#
#
# <img src="./images/install_import.png" width="400px">
#
# Before we do our last "Real-life case study", we need to install 3 modules that do not come pre-installed with `Anaconda`. There are several ways to install Python modules and libraries, here we will use `conda`. Note that normally you only need to install a module once (it will remain installed until you manually remove it).
#
# Most likely you already did this BEFORE the workshop started (instructions at the top of this manual). However, if you didn't here are the instructions to install the 3 modules (i.e. netcdf4, cartopy and cmocean). I'll explain what these modules do later.
#
#
# When you need to install additional Python modules or libraries, you will need the **Anaconda Prompt** if you are in Windows, or if you are a Mac user, you can simply use Mac's built it terminal.
#
# In Windows, search in the taskbar for **"Anaconda Prompt"** (in Mac, search for **"terminal"** in the Launchpad). The terminal should look a bit like this:
#
# <img src="./images/terminal.png" width="600px">
#
# -------------------
#
# <span class="important"></span> In the following section we will need the modules `netcdf4`, `catopy` and `cmocean`. You probably installed this BEFORE the beginning of this workshop. However, if you haven't installed them yet.... take a look at the instructions at the top of this document.

# %% [markdown]
# ---------------------------
#
# ## Real-life case study #3: Sea Surface Temperature from Satellites
#
#
# <img src="images/poes-750.jpg" width="600px">
#
# Some satellites can measure Sea Surface Temperature (SST) using optical sensors that capture infrared radiation coming from the ocean.
# <br>
#
# <span class="important"></span> If you haven't installed `netcdf4`, `catopy` and `cmocean` yet.... take a look at the section at the top of this document.
#
# ----------
#
# For the following section, you will need to have the data file <span class="file">satellite_data.nc</span>, already downloaded in your working directory (you probably already did this before the start of this workshop). Note that this is a "NetCDF" file, which is a binary format very compressed, made to store and transfer large datasets, but you cannot just open it in Excel. That is why we installed the `netcdf4` module.
#
# -----------
#
# In Spyder's **Editor** open a new file and save it as
# <span class="file"satellite.pyc</span`. Copy-paste the code below and click <span class='run'></span>
#
# Note that the code below is pretty much "the real deal". It is as complicated as it gets with Python, yet it is just a series of statements declaring variables and applying functions and methods. Note that, **by convention**, at the top of the file you import all the modules yo need.
#
# <div class="use_editor"></div>>.

# %%
import netCDF4
import numpy as np 
import matplotlib.pyplot as plt 
import cartopy.crs as ccrs
import cartopy.feature as cfeature 
import cmocean 

# open NetCDF data
nc = netCDF4.Dataset('./data/satellite_data.nc')
ncv = nc.variables

# Extract variables of interest from inside the NetCDF file
lon = ncv['longitude'][:]
lat = ncv['latitude'][:]
sst = ncv['sstMasked'][0,:,:]

# Make grids of lats and lons for later use to make maps
lons, lats = np.meshgrid(lon,lat) #Note that you can create 2 variables (lons and lats) in one single statement


#%% Create map (PlateCarree Projection) 
fig = plt.figure(figsize=(10,10)) # Create figure
ax = plt.axes(projection=ccrs.PlateCarree()) # Create axis within figure (with projection)
ax.pcolormesh(lons, lats, sst, transform=ccrs.PlateCarree()) # Add colormap to axis (specifying projection of data) 
ax.coastlines(resolution='10m') # Add coastline to axis

# %% [markdown]
# Take a look at the generated map. You can see the colder water at the north, and warmer water in the center of the map.
#
# What do you think is the average temperature in the whole map?
#
# Luckily this is easy to find by applying the **.mean** method to out Sea Surface Temperature data (sst):
#
# <div class="use_console"></div>

# %%
sst.mean()
# Out:
# 26.957568529476692

# %% [markdown]
# Lets see if you can figure out what are the minimum and the maximum temperatures is sst.

# %% [markdown]
# <div class="Q"><br>
#
# What is the **minimum** recorded Sea Surface Temperature in the sst data?   <br><br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# What is the **maximum** recorded Sea Surface Temperature in the sst data?   <br><br>
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ### Nicer maps (cartopy)
#
# Lets do a slightly fancier map of the same data. This time using a "Lamber Conformal Conic Projection".
#
# Since the satellite data is still "in memory" (assuming that you executed the code above, and did not turn off your computer since then), we can simply create the new map with the new projection.
#
# In this map we added some extra labels, colorbar and shadeRelief.
#
# We'll only use this map once, thus we can copy-paste into the "Console":
#
# <div class="use_console"></div>

# %%
#%% Create map (LambertConformal Projection)
# Create figure
fig = plt.figure(figsize=(13,13))
# Create axis within figure (with projection)
ax = plt.axes(projection=ccrs.LambertConformal(central_longitude=(lon.max()+lon.min())/2, central_latitude=(lat.max()+lat.min())/2)) 
# Add colormap to axis (specifying projection of data) 
cs = ax.pcolormesh(lons, lats, sst, cmap=cmocean.cm.thermal, transform=ccrs.PlateCarree()) 
# Add colorbar
cbar = fig.colorbar(cs, shrink=0.6, orientation='vertical', extend='both') 
# Add legend to colorbar
cbar.set_label('Sea Surface Temperature ($^\circ$C)') 
 # Add land to axis
ax.add_feature(cfeature.NaturalEarthFeature(category='physical', scale='10m',facecolor='none', name='coastline'),
               edgecolor='#666666', facecolor='#bfbfbf')
# Add gridlines to axis
ax.gridlines()
# Add title to figure
plt.title('Satellite SST (3-day composite)')
# Out:
# Text(0.5, 1.0, 'Satellite SST (3-day composite)')

# %% [markdown]
# Cartopy is a powerful module to create maps. We don't have time to deep-dive into it today, but feel free to explore other projections and make some extra maps. Here are some Galleries:
#
# https://scitools.org.uk/cartopy/docs/latest/gallery/index.html

# %% [markdown]
# <div class="Q"><br>
#
# From the code above... which of the following are **"functions"** or **"methods"**?
#
# Note that these **"functions"** or **"methods"** have fixed names, the coder has no choice but to use the correct **"function"** or **"method"** names.
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# From the code above... which of the following are **"variables"**?
#
# Note that these **variables** have names that the coder chose (e.g. a coder can write **a** = 1  ... or **b** = 1 ... or **alpha** = 1 ... or **my_variable** = 1).
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# From the code above... in the line  <br>
#
#     fig = plt.figure(figsize=(13,13))
#
# What is **fig**?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# From the code above... in the line  <br>
#
#     fig = plt.figure(figsize=(13,13))
#
# What is **plt.figure**?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <div class="Q"><br>
#
# From the code above... in the line  <br>
#
#     cbar = fig.colorbar(cs, shrink=0.6, orientation='vertical', extend='both') )
#
# What is **.colorbar**?
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# ## Data Management with ERDDAP
# <img src="./images/ERDDAP.png" width="700px">">
#
# Data management (as an administrator) is a complicated topic that requires months of training to do properly. But in summary, if you have oceanographic data that you need to store, manage, and serve to end-users... you should look into ERDDAP!
#
# ERDDAP:
# * It was developed by NOAA as a free open-source software.
# * Allows computer-human downloads (i.e. through a browser).
# * Allows computer-computer downloads (i.e. no browser. E.g. download data using Python, R, Matlab, etc.).
# * Many Governments and Oceanographic Institutions now serve their data using ERDDAP.
#
# Setting up an ERDDAP server (the administrator's job) is beyond the scope of this workshop. However, learning how to use it (as a client, or end-user) is easy, and incredibly useful.
#
# Here is a list of a few ERDDAP servers:

# %% [markdown]
# * NOAA CoastWatch: https://coastwatch.noaa.gov/erddap/index.html
# * Dalhousie University CEOTR: https://ceotr.ocean.dal.ca/erddap/index.html
# * Biological & Chemical Oceanography Data Management Office: https://erddap.bco-dmo.org/erddap/index.html
# * University of Hawaii: https://erddap.bco-dmo.org/erddap/index.html
# * PermafrontNet: https://data.permafrostnet.ca/erddap/index.html
# * University of British Columbia: https://salishsea.eos.ubc.ca/erddap/index.html

# %% [markdown]
# You can also use the following ERDDAP search engine to find ERRAP servers around the world: http://erddap.com/

# %% [markdown]
# ---------------------------------
#
# ### Example of using an ERDDAP server
#
# Go to https://coastwatch.noaa.gov/erddap/index.html <br>
#
# On the search box (top-right), search for: SST <br>
#
# You should see a list of data products. Find the product named "Sea Surface Temperature, NOAA Coral Reef Watch Daily Global 5km Satellite SST (CoralTemp), 1985-present, Daily". <br>
#
# Click on the "graph" link for that product (see arrow in image below) <br>
#
# <img src="./images/ERDDAP2.png" width="700px">
#
# You should be able to see a webpage similar to the one below:
#
# <img src="./images/ERDDAP.png" width="700px">

# %% [markdown]
# From here, you should be able to click on the map (to center) and zoom in or out to get the region that you are interested in.
#
# Then, on the field `Then set the File Type:` select `.nc`
#
# Then, click on `Download the Data or an Image`
#
# This should trigger a download of the data into your "Downloads" folder. Move this newly downloaded file to your **"WYTEC2_Python_Workshop/data"** folder.
#
# In my case the downloaded file was named `noaacrwsstDaily_2830_f4c9_5547_U1710527396048.nc`, but for you it will be a different name.
#
# -----------
#
# In Spyder's **Editor** open a new file and save it as <span class="file">new_plot.py</span>.
#
# Copy-paste the code below.
#
# <span class="important"></span> Make sure you change the filename to reflect the filename of **YOUR** downloaded file
#
# ... click <span class='run'></span>
#
# <br>
# <div class="use_editor"></div

# %%
import netCDF4
import numpy as np 
import matplotlib.pyplot as plt 
import cartopy.crs as ccrs 

# open NetCDF data. Use the filename of YOUR dowloaded file!!
nc = netCDF4.Dataset('noaacrwsstDaily_2830_f4c9_5547_U1710527396048.nc') #Use filename of YOUR downloaded file
ncv = nc.variables

# %% [markdown]
# The code above loaded the `.nc` file. Now you have to dig in the file and see information about the variables that are included in the file. The information you need is (1) variable names, and (2) their dimenssions. To figure that out type the following in the console:
#
# <div class="use_console"></div>

# %%
ncv
# Out:
# {'time': <class 'netCDF4._netCDF4.Variable'>
#  float64 time(time)
#      _CoordinateAxisType: Time
#      actual_range: [1.7103312e+09 1.7103312e+09]
#      axis: T
#      coverage_content_type: coordinate
#      ioos_category: Time
#      long_name: Time
#      standard_name: time
#      time_origin: 01-JAN-1970 00:00:00
#      units: seconds since 1970-01-01T00:00:00Z
#  unlimited dimensions:
#  current shape = (1,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'latitude': <class 'netCDF4._netCDF4.Variable'>
#  float32 latitude(latitude)
#      _CoordinateAxisType: Lat
#      actual_range: [-15.375  18.225]
#      axis: Y
#      comment: equirectangular projection and grid centers
#      coverage_content_type: coordinate
#      ioos_category: Location
#      long_name: Latitude
#      standard_name: latitude
#      units: degrees_north
#      valid_max: 89.975
#      valid_min: -89.975
#  unlimited dimensions:
#  current shape = (673,)
# ...

# %% [markdown]
# -----------------
#
# As you can see, the variables (and thier shapes) in the `.nc` file are:
#
# * 'time', shape = (1,)
# * 'latitude', shape = (673,)
# * 'longitude', shape = (673,)
# * and 'analysed_sst', shape = (1, 673, 673)
#
# Now we'll use the code below to extract these variables from the `.nc` file into Python variables that are easy to handle. Copy-paste the code below into your <span class="file">new_plot.py</span> file and click [run].
#
# <br>
# <div class="use_editor"></div>

# %%
# Extract variables of interest from inside the NetCDF file
lon = ncv['longitude'][:]
lat = ncv['latitude'][:]
data = ncv['analysed_sst'][0,:,:]

# %% [markdown]
# Finally, lets make a grid... and plot the data, by copy-pasting the code below into your <span class="file">new_plot.py</span> file and click [run].
#
# <br>
# <div class="use_editor"></div>

# %%
# Make grids of lats and lons for later use to make maps
lons, lats = np.meshgrid(lon,lat)

#%% Create map (PlateCarree Projection) 
fig = plt.figure(figsize=(7,7)) # Create figure
ax = plt.axes(projection=ccrs.PlateCarree()) # Create axis within figure (with projection)
ax.pcolormesh(lons, lats, data, transform=ccrs.PlateCarree()) # Add colormap to axis (specifying projection of data) 
ax.coastlines(resolution='10m') # Add coastline to axis

# %% [markdown]
# Note that this data (i.e. "Sea Surface Temperature, NOAA Coral Reef Watch Daily Global 5km Satellite SST" aka: CoralTemp) is similar to the previous example that we just did before. But this data set does not have any gaps, because it is a composite of several gap-free data products.
#
# Try exploring other data products from ERDDAP. As long as you choose "MAPS" (i.e. 2-dimensional geospatial products), you should be able to adapt the code above. Just pay attention to the name of the variables and their shapes.
# )

# %% [markdown]
# # **This is the end of lab**
#
# *******************
# *******************
#
# Code below is for formatting of this lab. Do not alter!

# %%
# Loads css file and applies it to lab HTML
from IPython.core.display import HTML
def css():
    style = open("../css/custom.css", "r").read()
    return HTML(style)
css()
# Out:
# <style>
#
# body {
#   counter-reset: question_num;                     /* Set a counter named 'section', and it`s initial value is 0. */
# }
#
# /* Question Box */
# .Q {
#     background-color:#ff9900;
#     color:black;
#     font-size:17px;
#     width:100%;
#     border:1px solid #666666;
#     padding:5px;
# }
#
# .Q::before {
#     counter-increment: question_num;
#     content: "QUESTION " counter(question_num) '\A';
#     white-space: pre;
# }
#
# .qhelp {
#     color:#666666;
#     font-size:10px
# }
#
# .qhelp::after {
#     content: "This is just to practice, you don't have to submit anything."
# }
#
#
#
# /* code */
# .rendered_html pre, .rendered_html code {
#     font-family: "SF Mono","Segoe UI Mono","Roboto Mono","Ubuntu Mono",Menlo,Courier,monospace;
#     padding: 1px 3px;
#     border: 1px solid #e6e6e6;
#     border-radius: 3px;
#     background: #e6e6e6;
#     font-size: 12px;
#     line-height: 1.4;
#     color: #0052CC;
# }
#
#
#
# .codeX {
# ...
